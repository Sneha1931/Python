# %%
import pandas as pd

# %%
pd
#pd is name given to pandas package.
# Out:
# <module 'pandas' from 'C:\\Users\\Sneha\\anaconda3\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
print("hello world!!!",24)
print(6)
print(12*10)
# Out:
# hello world!!! 24
# 6
# 120

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
""" This is an IF - ELSE STATEMENT """ #MULTILINE STRING
p=25
if(p<24):
    print("smaller than 24.")
else:
    print("greater than 24.")
# Out:
# greater than 24.

# %%
import hashlib

# %%
pip install tensorflow
# Out:
# ...
#      ---------------------------------------- 0.0/46.2 kB ? eta -:--:--
#      ---------------------------------------- 46.2/46.2 kB 2.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/377.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/377.0 MB 1.9 MB/s eta 0:03:17
#    ---------------------------------------- 0.1/377.0 MB 2.8 MB/s eta 0:02:14
#    ---------------------------------------- 0.2/377.0 MB 1.8 MB/s eta 0:03:34
#    ---------------------------------------- 0.3/377.0 MB 1.8 MB/s eta 0:03:34
#    ---------------------------------------- 0.4/377.0 MB 1.9 MB/s eta 0:03:24
#    ---------------------------------------- 0.5/377.0 MB 1.8 MB/s eta 0:03:25
#    ---------------------------------------- 0.6/377.0 MB 1.9 MB/s eta 0:03:19
#    ---------------------------------------- 0.6/377.0 MB 1.8 MB/s eta 0:03:28
#    ---------------------------------------- 0.8/377.0 MB 1.9 MB/s eta 0:03:15
# ...

# %% [markdown]
# PRINT AND ESCAPE SEQUENCE STATEMENTS

# %%
# with using hash we can write COMMENTS
# by using ctrl+/ we can comment and undo our statements
# using """ and  ''' also we can comment ... that is multiline comments.
print("hellooo ...\"lets go!\" \n starting again!")
# Out:
# hellooo ..."lets go!"
#  starting again!

# %%
print("hey !" , 2 ,12,sep="~",end="\n009\n")
# Out:
# hey !~2~12
# 009

# %% [markdown]
# VARIABLES AND DATA TYPES

# %%
a=1910
s=3101
print(a)
b="sneha"
print (b)
c= True
print(c)
d= None
print(d)
print(a+s)
print("the type of a is:",type(a))
print("the type of b is:",type(b))
print("the type of c is:",type(c))
print("the type of d is:",type(d))
p=complex(2,3)
print(p)
# Out:
# 1910
# sneha
# True
# None
# 5011
# the type of a is: <class 'int'>
# the type of b is: <class 'str'>
# the type of c is: <class 'bool'>
# the type of d is: <class 'NoneType'>
# (2+3j)

# %% [markdown]
# SEQUENCED DATA : List (mutable,[ ]) ,Tuple(immutable ,( ) )

# %%
list = [ 2,3.4,[9,-8],["apple","banana"]]
print(list)
# Out:
# [2, 3.4, [9, -8], ['apple', 'banana']]

# %% [markdown]
# tuple = (2,9,-3,("hey","girl"),0.8)
# print(tuple)

# %% [markdown]
# MAPPED DATA: dictionary{ }

# %%
dict={"name":"Sneha","äge":20,"canvote": True}
print(dict)
# Out:
# {'name': 'Sneha', 'äge': 20, 'canvote': True}

# %% [markdown]
# OPERATORS

# %%
print(9+5)  #add
print(9-5)  #subtract
print(9*5)  #multiply
print(9/5)  #division
print(9//5) #floor division
print(9**5) #exponential
print(9%5)  #modulo
# Out:
# 14
# 4
# 45
# 1.8
# 1
# 59049
# 4

# %% [markdown]
# TYPECASTING

# %%
#explicit typecasting
#string to integer
a = "1"
b= "90"
print(int(a)+int(b))
#implicit typecasting
c=1.9
d=100
print(type(c),type(d))
print(c+d)
# Out:
# 91
# <class 'float'> <class 'int'>
# 101.9

# %% [markdown]
# TAKING USER INPUT

# %%
a=input()
print(a)
a=input("enter name:")
print("my name is :",a)
# Out:
#  ayush
# ayush
# enter name: Sneha
# my name is : Sneha

# %%
x=input("enter first number:")
y=input("enter second number:")
print(int(x)+int(y))
x=input()
y=input()
print(x+y)
# Out:
# 5
# snehashruti
